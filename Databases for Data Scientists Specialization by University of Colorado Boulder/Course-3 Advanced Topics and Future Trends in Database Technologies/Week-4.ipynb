# %% [markdown]
# # <font color= blue> DATABSES FOR DATA SCIENTIST SPECIALIZATION BY UNIVERSITY OF COLORADO BOULDER</font>  #

# %% [markdown]
# ## Week-4 of course 3-Advanced Topics and Future Trends In Database Technologies ##

# %% [markdown]
# ## Learning Objectives ##
# - The "Relational Problem" and the NoSQL Solution
# - Popular NoSQL Solutions - MongoDB and Cassandra

# %% [markdown]
# There is no doubt that Relational Database are most comfortable and easy to work with. However with that big data explosion we can see that relational database systems really struggle to handle the volume, velocity and variety of big data.
#
# ![Screenshot from 2023-08-09 16-48-37.png](attachment:cd737c2b-8364-40d0-bd2c-e8a11e85cd28.png) ![Screenshot from 2023-08-09 16-50-32.png](attachment:47634a17-e609-4e30-9ed2-fc2b25241491.png)
#
# One approach for this problem could be that we can keep using relation database but enhance them to better handle the demands of Big Data
# ![Screenshot from 2023-08-09 16-56-24.png](attachment:f5558465-c789-4417-981e-58daad629a2e.png)

# %% [markdown]
# ![Screenshot from 2023-08-09 17-09-33.png](attachment:1c6592f4-aadb-485b-8a96-53fccbd810ba.png)

# %% [markdown]
# ![Screenshot from 2023-08-09 17-45-32.png](attachment:621efb59-d83d-4170-824a-9bbaf3d4b95a.png)  ![Screenshot from 2023-08-09 17-45-40.png](attachment:beb6c88b-bb07-4841-b6c7-c5d0cf06bf91.png)
